# %% [markdown]
# # Test 2D Levy flight in a switching fitness landscape
# <!-- ## The flights in each dimension are dependent -->
#
# Potential interpolated from grid data, `./input/landscape1.csv` and `./input/landscape2.csv`
# Grid data for potential taken from `/home/ochab/Dropbox/backup/ecoli/maple/fitness_new03a.mw`

# %% [markdown]
# # Uwaga!
# Wykomentowane
#
# <!-- Levy Flight jako proces symulujący spacer po krajobrazie dostosowania jest trudny matematycznie, bo:
#
# 1. Powoduje problemy numeryczne na brzegach: Gdy x lub y jest blisko 0, to przy używanym tutaj potencjale (-funkcja fitness) włącza się adaptacyjny bardzo mały krok czasowy i symulacja się zawiesza. Można ustalić sztuczne ograniczenie na krok czasowy, ale to oznacza, że numerycznie symulacja już nie produkuje ścisłego matematycznie lotu Levy'ego.
#
# Inne problemy:
#
# 2. Potrzeba zdefiniować warunki brzegowe w x,y=0.
#     1. Wcześniej zdefiniowałam pozostawanie w poprzednim punkcie.
#     2. Teraz zdefiniowałam losowanie do skutku.
#     Jest to tak czy inaczej arbitralne.
# 3. Potrzeba zdefiniować warunki brzegowe w sytuacji, gdy fitness < 0
# 4. Nawet przy takich sztucznych ustawieniach, histogramy z wielu symulacji pokazują, że trajektorie pałętają się głównie przy brzegach x=0, y=0. Dlaczego? Przecież fitness ma globalne maksimum gdzie indziej.
#     1. Wygląda na to, że zależy to od warunków początkowych.
#     2. Reprezentatywne próbkowanie całej przestrzeni jest niemożliwe, zajmie za dużo czasu obliczeniowego.
# 5. Trzeba by odrzucać możliwość ewolucji w dół fitness.
# 6. Zrobić nową gałąź do tej symulacji. -->

# %% [markdown]
# ## Definitions

# %%
import matplotlib.pyplot as plt
from matplotlib import cm
import numpy as np
import pandas as pd
import random
import time
from run import run

# %%
def generate_ax_traj(ax:plt.axes, trajdf:pd.DataFrame) -> None:    
    """Generate plt.axes object that plots a trajectory saved in trajdf.

    Args:
        ax (plt.axes): Plot content
        trajdf (pd.DataFrame): Trajectory data frame with columns: 'x' and 'y'
    """    
    if trajdf is not None:
            ax.plot(trajdf.x,trajdf.y, color='black')
    return


def generate_ax_pcolormesh(
        fig:plt.figure, 
        ax:plt.axes, 
        axtitle:str, 
        df:pd.DataFrame, 
        z_column:str, 
        fmin:float, 
        fmax:float
        )-> None:
    """Generate plt.axes object that plots a colormesh.

    Args:
        fig (plt.figure): Figure (needed for colorbar() (???))
        ax (plt.axes): Plot content
        axtitle (str): Plot title
        df (pd.DataFrame): Dataframe with columns: x='kmr', y='kr', z=z_column
        z_column (str): z column title
        fmin (float): Minimal z value of the color mesh
        fmax (float): Maximal z value of the color mesh
    """        
    nx = int( df['kmr'].max() - df['kmr'].min() + 1)
    ny = int( df['kr'].max() - df['kr'].min() + 1)

    x = df['kmr'].values.reshape(nx,ny).T
    y = df['kr'].values.reshape(nx,ny).T
    z = df[z_column].values.reshape(nx,ny).T

    c = ax.pcolormesh(x,y,z,vmin=fmin, vmax=fmax, cmap = plt.cm.jet)

    ax.set_title(axtitle)
    ax.set_xlabel('kmr')
    ax.set_ylabel('kr')
    fig.colorbar(c , ax=ax) 
    return

def plot_figures(
        dflist:list, 
        z_column:str, 
        fmin:list=[], 
        fmax:list=[],
        trajdf:pd.DataFrame=None
        )-> None:
    """Plot any number of figures side by side.

    Args:
        dflist (list): List of dataframes containing the color mesh data
        z_column (str): z column title for the dataframes containing the color mesh data
        fmin (list, optional): Minimal z value of the color mesh. Defaults to [].
        fmax (list, optional): Maximal z value of the color mesh. Defaults to [].
        trajdf (pd.DataFrame, optional): Trajectory data frame with columns: 'x' and 'y'. Defaults to None.
    """    
    fig, ax = plt.subplots(1,len(dflist),  figsize=(4.5*len(dflist), 3))

    for i in range (len(dflist)):
        if len(dflist)==1:
            Ax=ax
            title = z_column
        else:  
            Ax = ax[i]
            title = z_column+str(i)

        if len(fmin)>0:
            v_min=fmin[i]
        else:
            v_min=None
        if len(fmax)>0:
            v_max=fmax[i]
        else:
            v_max=None    

        generate_ax_traj(ax=Ax, trajdf=trajdf)
    
        generate_ax_pcolormesh(
            fig=fig, 
            ax=Ax, 
            axtitle=title, 
            df=dflist[i], 
            z_column=z_column, 
            fmin=v_min, 
            fmax=v_max
            )

    plt.show()
    return

# %%
input_dir="./input/"
input_data_file1 = "landscape1.csv"
input_data_file2 = "landscape2.csv"
input_data_files=[input_data_file1,input_data_file2]
potentialfile1 = input_dir+input_data_file1
potentialfile2 = input_dir+input_data_file2
output_dir="./output/"
output_log_file="out.log"

# %%
Ndatafiles=2
dfv=[]
for i in range (Ndatafiles):
    dfv.append(pd.read_csv(input_dir+input_data_files[i]))

# %%
display(dfv[0])
display(dfv[1])
# Out:
#         kmr     kr  fitness
# 0       1.0    1.0   -574.1
# 1       1.0    2.0   -573.2
# 2       1.0    3.0   -572.3
# 3       1.0    4.0   -571.4
# 4       1.0    5.0   -570.5
# ...     ...    ...      ...
# 9995  100.0   96.0   6202.0
# 9996  100.0   97.0   6292.0
# 9997  100.0   98.0   6382.0
# 9998  100.0   99.0   6472.0
# 9999  100.0  100.0   6562.0
#
# [10000 rows x 3 columns]
#         kmr     kr  fitness
# 0       1.0    1.0 -23575.0
# 1       1.0    2.0 -23575.0
# 2       1.0    3.0 -23575.0
# 3       1.0    4.0 -23575.0
# 4       1.0    5.0 -23575.0
# ...     ...    ...      ...
# 9995  100.0   96.0 -22822.0
# 9996  100.0   97.0 -22812.0
# 9997  100.0   98.0 -22802.0
# 9998  100.0   99.0 -22792.0
# 9999  100.0  100.0 -22782.0
#
# [10000 rows x 3 columns]

# %% [markdown]
# Until now, we have had the potential landscape (optimum=minimum): `dfv`
#
# For plotting, we prefer the data as a fitness landscape (optimum=maximum): `dff`

# %% [markdown]
# ## Convert potential landscape to fitness landscape

# %%
plot_figures(dfv, z_column='fitness')

# %% [markdown]
# These are potential landscapes. Max fitness = min potential.

# %% [markdown]
# We create `dff`: fitness landscape = -potential:

# %%
# Real copy
dff=[df.copy(deep=True) for df in dfv]
for df in dff:
    df['fitness']=-df['fitness']

# %% [markdown]
# The differences between the landscapes are unnoticeable. We check this below.

# %% [markdown]
# ## Check how much the landscapes differ between each other, apart from the difference by a constant.

# %% [markdown]
# ### Subtract the landscapes
#
# If the landscapes differ by a constant only, the difference will be constant.

# %%
dfdiff = pd.DataFrame()
dfdiff=dfv[i][['kmr','kr']]
dfdiff['fitness0'] = dfv[0][['fitness']]
dfdiff['fitness1'] = dfv[1][['fitness']]
dfdiff['fitness difference'] = dfv[1]['fitness']-dfv[0]['fitness']
display(dfdiff)
# Out:
#         kmr     kr  fitness0  fitness1  fitness difference
# 0       1.0    1.0    -574.1  -23575.0            -23000.9
# 1       1.0    2.0    -573.2  -23575.0            -23001.8
# 2       1.0    3.0    -572.3  -23575.0            -23002.7
# 3       1.0    4.0    -571.4  -23575.0            -23003.6
# 4       1.0    5.0    -570.5  -23575.0            -23004.5
# ...     ...    ...       ...       ...                 ...
# 9995  100.0   96.0    6202.0  -22822.0            -29024.0
# 9996  100.0   97.0    6292.0  -22812.0            -29104.0
# 9997  100.0   98.0    6382.0  -22802.0            -29184.0
# 9998  100.0   99.0    6472.0  -22792.0            -29264.0
# 9999  100.0  100.0    6562.0  -22782.0            -29344.0
#
# [10000 rows x 5 columns]

# %%
plot_figures([dfdiff], z_column='fitness difference')

# %% [markdown]
# Above, we can see the differences between the landscapes. We visualize this below.

# %% [markdown]
# ### Plot both landscapes next to each other with min values fixed

# %% [markdown]
# #### Minimal Z coordinate (color) fixed on plots: Attempt 4
#
# (See [`LevyFlight09.ipynb`](LevyFlight09.ipynb) for previous attempts)
#
# Minimal values: $fitness(1,1) + (fitness_{max}-fitness_{min})/15$.
#
# Maximal values: $fitness(1,1) + const.$

# %% [markdown]
# const.=700

# %%
f=[dff[i]['fitness'].iloc[0] -(dff[i]['fitness'].max()-dff[i]['fitness'].min())/15 \
   for i in range(Ndatafiles)]

fmin=np.array(f)

fmax=fmin+700

display(fmin, fmax)
# Out:
# array([   89.17      , 23520.46666667])
# array([  789.17      , 24220.46666667])

# %%
plot_figures(dflist=dff,  z_column='fitness',fmin=fmin, fmax=fmax)

# %% [markdown]
# ### Summary
#
# We can see that both landscapes are similar but landscape 1 is flatter than landscape 0.

# %% [markdown]
# ## Run simulation

# %%
T1=10.0
Ntraj1=1
dt1= 0.1 #0.001
minDt = 0. #1e-1
eta=0.1
D = 2. #1. #0.1
gamma = 1. #0.5
# alpha= # Will be given below
x0=5.
y0=5.
kr1=10.
kr2=20.
kmr1=90.
kmr2=100.
mean_landscape_switching_times=0.1

# %%
def test_alpha_param(alpha:float)->None:
   """Test simulation trajectories with a chosen value of the Levy flight parameter alpha.
   The function generates plots of the trajectory vs. time and the trajectory on the background of 
   two fitness landscapes (landscape 0 and landscape 1 switched in time during the simulation).

   Args:
       alpha (float): Levy flight parameter
   """

   output_data_file=f"outT{T1:.0e}N{Ntraj1:.0e}dt{dt1:.0e}_single_traj.csv"
   random.seed(time.time())
   run(
      output_dir,
      output_data_file,
      output_log_file,
      alpha=alpha, 
      D=D,
      gamma = gamma,
      dt=dt1, 
      minDt=minDt,
      eta=eta,
      T=T1, 
      t0=0., 
      x0=x0,
      y0=y0,
      kmr1=kmr1,
      kmr2=kmr2,
      kr1=kr1,
      kr2=kr2,
      mean_landscape_switching_times=mean_landscape_switching_times,
      Ntraj=Ntraj1,
      seed = random.randrange(100000), #785130160,
      potentialfile=potentialfile1,
      potentialfile_second=potentialfile2
      )



   print(open('./output/out.log', 'r').read()) 


   df=pd.read_csv(output_dir+output_data_file)

   fig, ax = plt.subplots(1,1)
   ax.plot(df.t, df.x , label=f"kmr, dt={dt1}")
   ax.plot(df.t, df.y , label=f"kr, dt={dt1}")
   ax.legend(loc='best', frameon=False)
   ax.set_xlabel("t")
   ax.set_ylabel("kmr, kr")
   f=[dff[i]['fitness'].iloc[0] -(dff[i]['fitness'].max()-dff[i]['fitness'].min())/15 \
      for i in range(Ndatafiles)]

   fmin=np.array(f)

   fmax=fmin+700
   plt.show()


   f=[dff[i]['fitness'].iloc[0] -(dff[i]['fitness'].max()-dff[i]['fitness'].min())/15 \
      for i in range(Ndatafiles)]

   fmin=np.array(f)

   fmax=fmin+700

   plot_figures(dflist=dff, z_column='fitness',fmin=fmin, fmax=fmax, trajdf=df)
   return

# %%
test_alpha_param(alpha=0.1)
# Out:
# alpha = 0.1
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 5000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 785130169
# Ntraj = 5000
# Only end points of the 5000 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# alpha = 0.1
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 10
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 69992
# Ntraj = 1
# mean_landscape_switching_times = 5
# Whole single trajectory will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_1traj_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Output written to STDOUT.
# Done.
#
# alpha = 1
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 10
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 50328
# Ntraj = 1
# mean_landscape_switching_times = 5
# Whole single trajectory will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_1traj_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Output written to STDOUT.
# Done.
#
# alpha = 1.9
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 10
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 44811
# Ntraj = 1
# mean_landscape_switching_times = 5
# Whole single trajectory will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_1traj_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Output written to STDOUT.
# Done.
#
# alpha = 0.1
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 10
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 46633
# Ntraj = 1
# mean_landscape_switching_times = 1
# Whole single trajectory will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_1traj_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Output written to STDOUT.
# Done.
#
# alpha = 1
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 10
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 13384
# Ntraj = 1
# mean_landscape_switching_times = 1
# Whole single trajectory will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_1traj_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Output written to STDOUT.
# Done.
#
# alpha = 0.1
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 10
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 86009
# Ntraj = 1
# mean_landscape_switching_times = 0.1
# Whole single trajectory will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_1traj_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Simulation stopped at:
# X: 95
# Y: 17
# Z: -674.1
# Output written to STDOUT.
# Done.

# %%
test_alpha_param(alpha=1.0)
# Out:
# alpha = 0.1
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 5000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 785130169
# Ntraj = 5000
# Only end points of the 5000 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# alpha = 0.1
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 10
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 69992
# Ntraj = 1
# mean_landscape_switching_times = 5
# Whole single trajectory will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_1traj_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Output written to STDOUT.
# Done.
#
# alpha = 1
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 10
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 50328
# Ntraj = 1
# mean_landscape_switching_times = 5
# Whole single trajectory will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_1traj_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Output written to STDOUT.
# Done.
#
# alpha = 1.9
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 10
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 44811
# Ntraj = 1
# mean_landscape_switching_times = 5
# Whole single trajectory will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_1traj_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Output written to STDOUT.
# Done.
#
# alpha = 0.1
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 10
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 46633
# Ntraj = 1
# mean_landscape_switching_times = 1
# Whole single trajectory will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_1traj_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Output written to STDOUT.
# Done.
#
# alpha = 1
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 10
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 13384
# Ntraj = 1
# mean_landscape_switching_times = 1
# Whole single trajectory will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_1traj_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Output written to STDOUT.
# Done.
#
# alpha = 0.1
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 10
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 86009
# Ntraj = 1
# mean_landscape_switching_times = 0.1
# Whole single trajectory will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_1traj_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Simulation stopped at:
# X: 95
# Y: 17
# Z: -674.1
# Output written to STDOUT.
# Done.
#
# alpha = 1
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 10
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 37303
# Ntraj = 1
# mean_landscape_switching_times = 0.1
# Whole single trajectory will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_1traj_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Output written to STDOUT.
# Done.

# %%
test_alpha_param(alpha=1.9)
# Out:
# alpha = 0.1
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 5000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 785130169
# Ntraj = 5000
# Only end points of the 5000 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# alpha = 0.1
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 10
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 69992
# Ntraj = 1
# mean_landscape_switching_times = 5
# Whole single trajectory will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_1traj_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Output written to STDOUT.
# Done.
#
# alpha = 1
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 10
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 50328
# Ntraj = 1
# mean_landscape_switching_times = 5
# Whole single trajectory will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_1traj_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Output written to STDOUT.
# Done.
#
# alpha = 1.9
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 10
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 44811
# Ntraj = 1
# mean_landscape_switching_times = 5
# Whole single trajectory will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_1traj_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Output written to STDOUT.
# Done.
#
# alpha = 0.1
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 10
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 46633
# Ntraj = 1
# mean_landscape_switching_times = 1
# Whole single trajectory will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_1traj_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Output written to STDOUT.
# Done.
#
# alpha = 1
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 10
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 13384
# Ntraj = 1
# mean_landscape_switching_times = 1
# Whole single trajectory will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_1traj_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Output written to STDOUT.
# Done.
#
# alpha = 0.1
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 10
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 86009
# Ntraj = 1
# mean_landscape_switching_times = 0.1
# Whole single trajectory will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_1traj_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Simulation stopped at:
# X: 95
# Y: 17
# Z: -674.1
# Output written to STDOUT.
# Done.
#
# alpha = 1
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 10
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 37303
# Ntraj = 1
# mean_landscape_switching_times = 0.1
# Whole single trajectory will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_1traj_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Output written to STDOUT.
# Done.
#
# alpha = 1.9
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 10
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 92293
# Ntraj = 1
# mean_landscape_switching_times = 0.1
# Whole single trajectory will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_1traj_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Output written to STDOUT.
# Done.

# %% [markdown]
# ## Generate an ensemble of trajectories, plot heatmap of points reached at a given time

# %%
def run_ensemble_simulation(alpha:float, T:float, Ntraj:int)->str:
    """Run ensemble simulation with a chosen value of the Levy flight parameter alpha.  
    The simulation switches landscape 0 and landscape 1 in time.
    The function generates a file with columns: t,x,y. t: simulation end (here: when
    the trajectory reaches the square ((kmr1,kmr2),(kr1,kr2))). x,y: coordinates of the
    last point of the trajectory.

    Args:
        alpha (float): Levy flight parameter
        T (float): max simulation time
        Ntraj (int) : number of trajectories in the ensemble
    Returns:
        output_data_file (str):
    """   
    output_data_file=f"outT{T1:.0e}N{Ntraj1:.0e}dt{dt1:.0e}alpha{alpha:.0e}_ensemble.csv"
    random.seed(time.time())
    
    run(
        output_dir,
        output_data_file,
        output_log_file,
        alpha=alpha, 
        D=D,
        gamma = gamma,
        dt=dt1, 
        minDt=minDt,
        eta=eta,
        T=T, 
        t0=0., 
        x0=x0,
        y0=y0,
        kmr1=kmr1,
        kmr2=kmr2,
        kr1=kr1,
        kr2=kr2,
        Ntraj=Ntraj,
        seed = random.randrange(100000),# 785130169,
        potentialfile=potentialfile1,
        potentialfile_second=potentialfile2
    )

    print(open('./output/out.log', 'r').read()) 
    return output_data_file


def plot_heatmap(output_data_file:str, alpha:float)->None:
    """Plot heatmap from the output data file columns x,y.

    Args:
        output_data_file (str):
        alpha (float): alpha parameter
    """    
    ensdf=pd.read_csv(output_dir+output_data_file)
    fig, ax = plt.subplots(1,1)
    Nbins = 100
    x_bins = np.linspace(0, 100, Nbins)
    y_bins = np.linspace(0, 100, Nbins)
    h = ax.hist2d(np.array(ensdf.x), np.array(ensdf.y), bins =[x_bins, y_bins], cmap = plt.cm.jet) 
    # nipy_spectral
    fig.colorbar(h[3] , ax=ax) 
    ax.set_xlabel('kmr')
    ax.set_ylabel('kr')
    ax.set_title("alpha={:.1f}".format(alpha))

    plt.tight_layout() 
    plt.show()
    return

def plot_fpt_hist(output_data_file:str, alpha:float)->tuple:
    """Plot a histogram from the output_data_file's 't' column.

    Args:
        output_data_file (str):
        alpha (float): alpha parameter

    Returns:
        (float, float): ('t' column mean, 't' column std dev)
    """    
    ensdf=pd.read_csv(output_dir+output_data_file)
    fig,ax=plt.subplots(1,1)
    plt.hist(ensdf['t'], bins=30, density=True)

    x_label = 'Time to reach the maximum region (({:.0f},{:.0f}),({:.0f},{:.0f})), T'.format(kmr1,kmr2,kr1,kr2)

    ax.set_xlabel(x_label) 
    ax.set_ylabel('Probability')  
    ax.set_title("alpha={:.1f}".format(alpha))  
    plt.show()     
    return


def get_fpt_mean_sd(output_data_file:str)->tuple:
    """Get 't' column mean, 't' column std dev from the file
    Args:
        output_data_file (str):

    Returns:
        (float, float): ('t' column mean, 't' column std dev)
    """       
    ensdf=pd.read_csv(output_dir+output_data_file)
    return(ensdf['t'].mean(), ensdf['t'].std())

# %%
alpha=0.1
T=10.
Ntraj=1000

output_data_file=run_ensemble_simulation(alpha=alpha, T=T, Ntraj=Ntraj);
mean_fpt, sd_fpt=get_fpt_mean_sd(output_data_file=output_data_file)
print('mean_fpt={}, sd_fpt={}'.format(mean_fpt,sd_fpt))
# Out:
# alpha = 0.1
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 1000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 29608
# Ntraj = 1
# Whole single trajectory will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_1traj_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Simulation stopped at:
# X: 90
# Y: 16
# Z: -693.33
# Output written to STDOUT.
# Done.
#
# alpha = 1
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 1000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 77022
# Ntraj = 1
# Whole single trajectory will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_1traj_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Simulation stopped at:
# X: 90
# Y: 18
# Z: -662.77
# Output written to STDOUT.
# Done.
#
# alpha = 1.9
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 1000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 45447
# Ntraj = 1
# Whole single trajectory will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_1traj_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Simulation stopped at:
# X: 92
# Y: 17
# Z: -681.15
# Output written to STDOUT.
# Done.
#
# alpha = 0.1
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 10
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 27877
# Ntraj = 1000
# Only end points of the 1000 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 9.62764
# Time simulation variance: 2.53826
# Output written to STDOUT.
# Done.
#
# alpha = 0.1
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 1000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 13431
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 56.814
# Time simulation variance: 2613.92
# Output written to STDOUT.
# Done.
#
# alpha = 0.1
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 1000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 19452
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 62.5681
# Time simulation variance: 2032.44
# Output written to STDOUT.
# Done.
#
# alpha = 0.2
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 1000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 35566
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 65.873
# Time simulation variance: 3243.22
# Output written to STDOUT.
# Done.
#
# alpha = 0.3
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 1000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 41779
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 48.6817
# Time simulation variance: 1846.52
# Output written to STDOUT.
# Done.
#
# alpha = 0.4
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 1000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 6557
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 64.559
# Time simulation variance: 3116.7
# Output written to STDOUT.
# Done.
#
# alpha = 0.5
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 1000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 69219
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 57.9608
# Time simulation variance: 3293.24
# Output written to STDOUT.
# Done.
#
# alpha = 0.6
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 1000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 31628
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 52.8576
# Time simulation variance: 1843.74
# Output written to STDOUT.
# Done.
#
# alpha = 0.7
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 1000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 8780
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 60.9965
# Time simulation variance: 2463.89
# Output written to STDOUT.
# Done.
#
# alpha = 0.8
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 1000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 38920
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 55.9125
# Time simulation variance: 1419.42
# Output written to STDOUT.
# Done.
#
# alpha = 0.9
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 1000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 75166
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 64.2292
# Time simulation variance: 2084.44
# Output written to STDOUT.
# Done.
#
# alpha = 1
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 1000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 57526
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 75.458
# Time simulation variance: 2941.15
# Output written to STDOUT.
# Done.
#
# alpha = 1.1
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 1000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 60428
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 81.6761
# Time simulation variance: 2786.07
# Output written to STDOUT.
# Done.
#
# alpha = 1.2
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 1000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 21797
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 90.1042
# Time simulation variance: 3388.09
# Output written to STDOUT.
# Done.
#
# alpha = 1.3
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 1000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 10740
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 109.929
# Time simulation variance: 5861.56
# Output written to STDOUT.
# Done.
#
# alpha = 1.4
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 1000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 31688
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 133.538
# Time simulation variance: 9370.01
# Output written to STDOUT.
# Done.
#
# alpha = 1.5
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 1000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 85608
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 193.009
# Time simulation variance: 22275.9
# Output written to STDOUT.
# Done.
#
# alpha = 1.6
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 1000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 74951
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 246.202
# Time simulation variance: 38174.9
# Output written to STDOUT.
# Done.
#
# alpha = 1.7
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 1000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 54423
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 386.063
# Time simulation variance: 82078.4
# Output written to STDOUT.
# Done.
#
# alpha = 1.8
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 1000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 20368
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 613.676
# Time simulation variance: 122615
# Output written to STDOUT.
# Done.
#
# alpha = 1.9
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 1000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 26760
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 768.135
# Time simulation variance: 104756
# Output written to STDOUT.
# Done.
#
# alpha = 0.1
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 10
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 99657
# Ntraj = 1000
# Only end points of the 1000 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 9.60435
# Time simulation variance: 2.76382
# Output written to STDOUT.
# Done.
#
#
# mean_fpt=9.604348082, sd_fpt=1.6633052934869745

# %% [markdown]
# The simulation returns mean FPT and variance of FPT.
#
# Additionally, I do the same reading from the output file: mean, std dev.

# %%
plot_heatmap(output_data_file=output_data_file, alpha=alpha)

# %% [markdown]
# Trajectories are supposed to stop at the square ((10,20),(90,100)).
# The square is brighter here because a part of the trajectories reached it and then the simulation was stopped. However, other trajectories did not make it to reach the square, hence the rest of the heat map.

# %% [markdown]
# ## Generate ensemble of trajectories

# %% [markdown]
# ###  First passage time histogram for a single set of simulation parameters

# %%
alpha=0.1
T=5000.
Ntraj=100

output_data_file=run_ensemble_simulation(alpha=alpha, T=T, Ntraj=Ntraj)

plot_fpt_hist(output_data_file=output_data_file, alpha=alpha)

print(output_data_file)
# Out:
# alpha = 0.1
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 5000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 30516
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 52.9728
# Time simulation variance: 1977.21
# Output written to STDOUT.
# Done.
# outT1e+03N1e+00dt1e-01alpha1e-01_ensemble.csv

# %% [markdown]
# # Calculate MFPT vs. $\alpha$
# # Unfinished

# %% [markdown]
# # TODO:
#
# * Get MFPT from the simulation
# * Control the landscape switching rate
# * Make noise weaker
# * Make Levy Flights less pronounced

# %%
T=5000.
Ntraj=100

data=[]
for alpha in np.arange(0.1,2.0,0.1):
    output_data_file=run_ensemble_simulation(alpha, T=T, Ntraj=Ntraj)
    plot_heatmap(output_data_file=output_data_file, alpha=alpha)
    plot_fpt_hist(output_data_file=output_data_file, alpha=alpha)
    mean_fpt, sd_fpt=get_fpt_mean_sd(output_data_file=output_data_file)
    data.append([alpha, mean_fpt,sd_fpt])

mfptdf=pd.DataFrame(data, columns=['alpha', 'mean_fpt','sd_fpt'])
# Out:
# alpha = 0.1
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 5000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 30516
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 52.9728
# Time simulation variance: 1977.21
# Output written to STDOUT.
# Done.
#
# alpha = 0.1
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 5000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 32143
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 63.313
# Time simulation variance: 3003.45
# Output written to STDOUT.
# Done.
# alpha = 0.1
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 5000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 30516
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 52.9728
# Time simulation variance: 1977.21
# Output written to STDOUT.
# Done.
#
# alpha = 0.1
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 5000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 32143
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 63.313
# Time simulation variance: 3003.45
# Output written to STDOUT.
# Done.
#
# alpha = 0.2
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 5000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 19982
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 53.3302
# Time simulation variance: 2103.78
# Output written to STDOUT.
# Done.
# alpha = 0.1
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 5000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 30516
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 52.9728
# Time simulation variance: 1977.21
# Output written to STDOUT.
# Done.
#
# alpha = 0.1
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 5000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 32143
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 63.313
# Time simulation variance: 3003.45
# Output written to STDOUT.
# Done.
#
# alpha = 0.2
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 5000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 19982
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 53.3302
# Time simulation variance: 2103.78
# Output written to STDOUT.
# Done.
#
# alpha = 0.3
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 5000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 51501
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 50.914
# Time simulation variance: 1735.1
# Output written to STDOUT.
# Done.
# alpha = 0.1
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 5000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 30516
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 52.9728
# Time simulation variance: 1977.21
# Output written to STDOUT.
# Done.
#
# alpha = 0.1
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 5000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 32143
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 63.313
# Time simulation variance: 3003.45
# Output written to STDOUT.
# Done.
#
# alpha = 0.2
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 5000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 19982
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 53.3302
# Time simulation variance: 2103.78
# Output written to STDOUT.
# Done.
#
# alpha = 0.3
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 5000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 51501
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 50.914
# Time simulation variance: 1735.1
# Output written to STDOUT.
# Done.
#
# alpha = 0.4
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 5000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 67417
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 51.6128
# Time simulation variance: 1796.7
# Output written to STDOUT.
# Done.
# alpha = 0.1
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 5000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 30516
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 52.9728
# Time simulation variance: 1977.21
# Output written to STDOUT.
# Done.
#
# alpha = 0.1
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 5000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 32143
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 63.313
# Time simulation variance: 3003.45
# Output written to STDOUT.
# Done.
#
# alpha = 0.2
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 5000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 19982
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 53.3302
# Time simulation variance: 2103.78
# Output written to STDOUT.
# Done.
#
# alpha = 0.3
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 5000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 51501
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 50.914
# Time simulation variance: 1735.1
# Output written to STDOUT.
# Done.
#
# alpha = 0.4
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 5000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 67417
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 51.6128
# Time simulation variance: 1796.7
# Output written to STDOUT.
# Done.
#
# alpha = 0.5
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 5000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 98115
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 53.3284
# Time simulation variance: 1838.85
# Output written to STDOUT.
# Done.
# alpha = 0.1
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 5000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 30516
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 52.9728
# Time simulation variance: 1977.21
# Output written to STDOUT.
# Done.
#
# alpha = 0.1
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 5000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 32143
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 63.313
# Time simulation variance: 3003.45
# Output written to STDOUT.
# Done.
#
# alpha = 0.2
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 5000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 19982
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 53.3302
# Time simulation variance: 2103.78
# Output written to STDOUT.
# Done.
#
# alpha = 0.3
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 5000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 51501
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 50.914
# Time simulation variance: 1735.1
# Output written to STDOUT.
# Done.
#
# alpha = 0.4
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 5000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 67417
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 51.6128
# Time simulation variance: 1796.7
# Output written to STDOUT.
# Done.
#
# alpha = 0.5
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 5000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 98115
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 53.3284
# Time simulation variance: 1838.85
# Output written to STDOUT.
# Done.
#
# alpha = 0.6
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 5000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 40396
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 59.1414
# Time simulation variance: 2307.21
# Output written to STDOUT.
# Done.
# alpha = 0.1
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 5000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 30516
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 52.9728
# Time simulation variance: 1977.21
# Output written to STDOUT.
# Done.
#
# alpha = 0.1
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 5000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 32143
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 63.313
# Time simulation variance: 3003.45
# Output written to STDOUT.
# Done.
#
# alpha = 0.2
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 5000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 19982
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 53.3302
# Time simulation variance: 2103.78
# Output written to STDOUT.
# Done.
#
# alpha = 0.3
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 5000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 51501
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 50.914
# Time simulation variance: 1735.1
# Output written to STDOUT.
# Done.
#
# alpha = 0.4
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 5000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 67417
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 51.6128
# Time simulation variance: 1796.7
# Output written to STDOUT.
# Done.
#
# alpha = 0.5
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 5000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 98115
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 53.3284
# Time simulation variance: 1838.85
# Output written to STDOUT.
# Done.
#
# alpha = 0.6
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 5000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 40396
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 59.1414
# Time simulation variance: 2307.21
# Output written to STDOUT.
# Done.
#
# alpha = 0.7
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 5000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 73325
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 60.1145
# Time simulation variance: 2705.58
# Output written to STDOUT.
# Done.
# alpha = 0.1
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 5000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 30516
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 52.9728
# Time simulation variance: 1977.21
# Output written to STDOUT.
# Done.
#
# alpha = 0.1
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 5000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 32143
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 63.313
# Time simulation variance: 3003.45
# Output written to STDOUT.
# Done.
#
# alpha = 0.2
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 5000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 19982
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 53.3302
# Time simulation variance: 2103.78
# Output written to STDOUT.
# Done.
#
# alpha = 0.3
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 5000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 51501
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 50.914
# Time simulation variance: 1735.1
# Output written to STDOUT.
# Done.
#
# alpha = 0.4
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 5000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 67417
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 51.6128
# Time simulation variance: 1796.7
# Output written to STDOUT.
# Done.
#
# alpha = 0.5
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 5000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 98115
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 53.3284
# Time simulation variance: 1838.85
# Output written to STDOUT.
# Done.
#
# alpha = 0.6
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 5000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 40396
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 59.1414
# Time simulation variance: 2307.21
# Output written to STDOUT.
# Done.
#
# alpha = 0.7
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 5000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 73325
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 60.1145
# Time simulation variance: 2705.58
# Output written to STDOUT.
# Done.
#
# alpha = 0.8
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 5000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 13920
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 55.1449
# Time simulation variance: 1555.64
# Output written to STDOUT.
# Done.
# alpha = 0.1
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 5000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 30516
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 52.9728
# Time simulation variance: 1977.21
# Output written to STDOUT.
# Done.
#
# alpha = 0.1
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 5000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 32143
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 63.313
# Time simulation variance: 3003.45
# Output written to STDOUT.
# Done.
#
# alpha = 0.2
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 5000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 19982
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 53.3302
# Time simulation variance: 2103.78
# Output written to STDOUT.
# Done.
#
# alpha = 0.3
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 5000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 51501
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 50.914
# Time simulation variance: 1735.1
# Output written to STDOUT.
# Done.
#
# alpha = 0.4
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 5000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 67417
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 51.6128
# Time simulation variance: 1796.7
# Output written to STDOUT.
# Done.
#
# alpha = 0.5
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 5000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 98115
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 53.3284
# Time simulation variance: 1838.85
# Output written to STDOUT.
# Done.
#
# alpha = 0.6
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 5000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 40396
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 59.1414
# Time simulation variance: 2307.21
# Output written to STDOUT.
# Done.
#
# alpha = 0.7
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 5000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 73325
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 60.1145
# Time simulation variance: 2705.58
# Output written to STDOUT.
# Done.
#
# alpha = 0.8
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 5000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 13920
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 55.1449
# Time simulation variance: 1555.64
# Output written to STDOUT.
# Done.
#
# alpha = 0.9
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 5000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 58795
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 67.3128
# Time simulation variance: 2741.52
# Output written to STDOUT.
# Done.
# alpha = 0.1
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 5000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 30516
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 52.9728
# Time simulation variance: 1977.21
# Output written to STDOUT.
# Done.
#
# alpha = 0.1
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 5000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 32143
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 63.313
# Time simulation variance: 3003.45
# Output written to STDOUT.
# Done.
#
# alpha = 0.2
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 5000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 19982
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 53.3302
# Time simulation variance: 2103.78
# Output written to STDOUT.
# Done.
#
# alpha = 0.3
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 5000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 51501
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 50.914
# Time simulation variance: 1735.1
# Output written to STDOUT.
# Done.
#
# alpha = 0.4
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 5000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 67417
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 51.6128
# Time simulation variance: 1796.7
# Output written to STDOUT.
# Done.
#
# alpha = 0.5
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 5000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 98115
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 53.3284
# Time simulation variance: 1838.85
# Output written to STDOUT.
# Done.
#
# alpha = 0.6
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 5000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 40396
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 59.1414
# Time simulation variance: 2307.21
# Output written to STDOUT.
# Done.
#
# alpha = 0.7
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 5000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 73325
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 60.1145
# Time simulation variance: 2705.58
# Output written to STDOUT.
# Done.
#
# alpha = 0.8
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 5000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 13920
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 55.1449
# Time simulation variance: 1555.64
# Output written to STDOUT.
# Done.
#
# alpha = 0.9
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 5000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 58795
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 67.3128
# Time simulation variance: 2741.52
# Output written to STDOUT.
# Done.
#
# alpha = 1
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 5000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 32930
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 63.3821
# Time simulation variance: 1714.66
# Output written to STDOUT.
# Done.
# alpha = 0.1
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 5000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 30516
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 52.9728
# Time simulation variance: 1977.21
# Output written to STDOUT.
# Done.
#
# alpha = 0.1
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 5000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 32143
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 63.313
# Time simulation variance: 3003.45
# Output written to STDOUT.
# Done.
#
# alpha = 0.2
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 5000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 19982
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 53.3302
# Time simulation variance: 2103.78
# Output written to STDOUT.
# Done.
#
# alpha = 0.3
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 5000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 51501
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 50.914
# Time simulation variance: 1735.1
# Output written to STDOUT.
# Done.
#
# alpha = 0.4
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 5000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 67417
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 51.6128
# Time simulation variance: 1796.7
# Output written to STDOUT.
# Done.
#
# alpha = 0.5
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 5000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 98115
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 53.3284
# Time simulation variance: 1838.85
# Output written to STDOUT.
# Done.
#
# alpha = 0.6
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 5000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 40396
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 59.1414
# Time simulation variance: 2307.21
# Output written to STDOUT.
# Done.
#
# alpha = 0.7
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 5000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 73325
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 60.1145
# Time simulation variance: 2705.58
# Output written to STDOUT.
# Done.
#
# alpha = 0.8
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 5000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 13920
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 55.1449
# Time simulation variance: 1555.64
# Output written to STDOUT.
# Done.
#
# alpha = 0.9
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 5000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 58795
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 67.3128
# Time simulation variance: 2741.52
# Output written to STDOUT.
# Done.
#
# alpha = 1
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 5000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 32930
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 63.3821
# Time simulation variance: 1714.66
# Output written to STDOUT.
# Done.
#
# alpha = 1.1
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 5000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 78592
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 84.7809
# Time simulation variance: 5637.12
# Output written to STDOUT.
# Done.
# alpha = 0.1
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 5000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 30516
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 52.9728
# Time simulation variance: 1977.21
# Output written to STDOUT.
# Done.
#
# alpha = 0.1
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 5000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 32143
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 63.313
# Time simulation variance: 3003.45
# Output written to STDOUT.
# Done.
#
# alpha = 0.2
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 5000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 19982
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 53.3302
# Time simulation variance: 2103.78
# Output written to STDOUT.
# Done.
#
# alpha = 0.3
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 5000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 51501
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 50.914
# Time simulation variance: 1735.1
# Output written to STDOUT.
# Done.
#
# alpha = 0.4
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 5000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 67417
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 51.6128
# Time simulation variance: 1796.7
# Output written to STDOUT.
# Done.
#
# alpha = 0.5
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 5000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 98115
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# ...
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 84.7809
# Time simulation variance: 5637.12
# Output written to STDOUT.
# Done.
#
# alpha = 1.2
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 5000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 56288
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 79.048
# Time simulation variance: 2254.36
# Output written to STDOUT.
# Done.
#
# alpha = 1.3
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 5000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 38446
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 103.264
# Time simulation variance: 3882.74
# Output written to STDOUT.
# Done.
#
# alpha = 1.4
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 5000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 58791
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 123.337
# Time simulation variance: 8286.41
# Output written to STDOUT.
# Done.
#
# alpha = 1.5
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 5000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 1766
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 189.368
# Time simulation variance: 13335.1
# Output written to STDOUT.
# Done.
#
# alpha = 1.6
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 5000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 29340
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 263.572
# Time simulation variance: 47867.8
# Output written to STDOUT.
# Done.
#
# alpha = 1.7
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 5000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 19648
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 387.778
# Time simulation variance: 94869.3
# Output written to STDOUT.
# Done.
#
# alpha = 1.8
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 5000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 78537
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 804.091
# Time simulation variance: 361587
# Output written to STDOUT.
# Done.
# alpha = 0.1
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 5000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 30516
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 52.9728
# Time simulation variance: 1977.21
# Output written to STDOUT.
# Done.
#
# alpha = 0.1
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 5000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 32143
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 63.313
# Time simulation variance: 3003.45
# Output written to STDOUT.
# Done.
#
# alpha = 0.2
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 5000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 19982
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 53.3302
# Time simulation variance: 2103.78
# Output written to STDOUT.
# Done.
#
# alpha = 0.3
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 5000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 51501
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 50.914
# Time simulation variance: 1735.1
# Output written to STDOUT.
# Done.
#
# alpha = 0.4
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 5000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 67417
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 51.6128
# Time simulation variance: 1796.7
# Output written to STDOUT.
# Done.
#
# alpha = 0.5
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 5000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 98115
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 53.3284
# Time simulation variance: 1838.85
# Output written to STDOUT.
# Done.
#
# alpha = 0.6
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 5000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 40396
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 59.1414
# Time simulation variance: 2307.21
# Output written to STDOUT.
# Done.
#
# alpha = 0.7
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 5000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 73325
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 60.1145
# Time simulation variance: 2705.58
# Output written to STDOUT.
# Done.
#
# alpha = 0.8
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 5000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 13920
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 55.1449
# Time simulation variance: 1555.64
# Output written to STDOUT.
# Done.
#
# alpha = 0.9
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 5000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 58795
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 67.3128
# Time simulation variance: 2741.52
# Output written to STDOUT.
# Done.
#
# alpha = 1
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 5000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 32930
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 63.3821
# Time simulation variance: 1714.66
# Output written to STDOUT.
# Done.
#
# alpha = 1.1
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 5000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 78592
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 84.7809
# Time simulation variance: 5637.12
# Output written to STDOUT.
# Done.
#
# alpha = 1.2
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 5000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 56288
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 79.048
# Time simulation variance: 2254.36
# Output written to STDOUT.
# Done.
#
# alpha = 1.3
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 5000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 38446
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 103.264
# Time simulation variance: 3882.74
# Output written to STDOUT.
# Done.
#
# alpha = 1.4
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 5000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 58791
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 123.337
# Time simulation variance: 8286.41
# Output written to STDOUT.
# Done.
#
# alpha = 1.5
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 5000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 1766
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 189.368
# Time simulation variance: 13335.1
# Output written to STDOUT.
# Done.
#
# alpha = 1.6
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 5000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 29340
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 263.572
# Time simulation variance: 47867.8
# Output written to STDOUT.
# Done.
#
# alpha = 1.7
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 5000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 19648
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 387.778
# Time simulation variance: 94869.3
# Output written to STDOUT.
# Done.
#
# alpha = 1.8
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 5000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 78537
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 804.091
# Time simulation variance: 361587
# Output written to STDOUT.
# Done.
#
# alpha = 1.9
# D = 2
# gamma = 1
# dt = 0.1
# minDt = 0
# eta = 0.1
# T = 5000
# t0 = 0
# x0 = 5
# y0 = 5
# potential_file = ./input/landscape1.csv
# potential_file_second = ./input/landscape2.csv
# kmr1 = 90
# kmr2 = 100
# kr1 = 10
# kr2 = 20
# seed = 66572
# Ntraj = 100
# Only end points of the 100 trajectories will be printed as the output.
# Running the simulation...
#
# -------------launch_2D_ensemble_potential_file()-----------
# potential_file=./input/landscape1.csv
# potential_file_second=./input/landscape2.csv
# Average time of simulation: 1785.3
# Time simulation variance: 1.94219e+06
# Output written to STDOUT.
# Done.

# %%
fig,ax=plt.subplots(1,1)
ax.plot(mfptdf['alpha'],mfptdf['mean_fpt'])
ax.set_xlabel('alpha')
ax.set_ylabel('MFPT')
plt.show()

# %% [markdown]
# # TODO:
#
# * Get MFPT from the simulation
# * Control the landscape switching rate
# * Make noise weaker
# * Make Levy Flights less pronounced
# * Seed is ignored, repeated simulations produce different results. Fix this.
# * Unify axes range on histograms.

# %% [markdown]
# # Fix this:

# %%
data=[]
T1=5e+03
Ntraj1=1e+03
dt1=1e-01
for alpha in np.arange(0.1,2.0,0.1):
    # plot_heatmap(output_data_file=output_data_file)
    # plot_fpt_hist(output_data_file=output_data_file)
    output_data_file=f"outT{T1:.0e}N{Ntraj1:.0e}dt{dt1:.0e}alpha{alpha:.0e}_ensemble.csv"

    # print(output_data_file)
    mean_fpt, sd_fpt=get_fpt_mean_sd(output_data_file=output_data_file)
    data.append([alpha, mean_fpt,sd_fpt])

mfptdf=pd.DataFrame(data, columns=['alpha', 'mean_fpt','sd_fpt'])

# %%
fig,ax=plt.subplots(1,1)
ax.plot(mfptdf['alpha'],mfptdf['mean_fpt'])
ax.set_xlabel('alpha')
ax.set_ylabel('MFPT')
plt.show()
